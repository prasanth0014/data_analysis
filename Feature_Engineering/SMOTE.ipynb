# %%
from sklearn.datasets import make_classification

X,y=make_classification(n_samples=1000,n_features=2,n_redundant=0,n_clusters_per_class=1,weights=[0.90,0.10],random_state=42)

# %%
import pandas as pd
X=pd.DataFrame(X,columns=["df1","df2"])
y=pd.DataFrame(y,columns=["target"])
final_df=pd.concat([X,y],axis=1)
final_df
# Out:
#           df1       df2  target
# 0    1.073546 -1.101339       0
# 1    0.755945 -1.172352       0
# 2    1.354479 -0.948528       0
# 3    3.103090  0.233485       0
# 4    1.951888 -0.270157       0
# ..        ...       ...     ...
# 995  1.713939  0.451639       1
# 996  1.509473 -0.794996       0
# 997 -2.150901 -2.989372       0
# 998  2.451647 -0.156629       0
# 999  3.641478  0.756925       0
#
# [1000 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
plt.scatter(final_df["df1"],final_df["df2"],c=final_df["target"])

# %%
# !pip install imblearn

# %%
from imblearn.over_sampling import SMOTE
smote=SMOTE()

# %%
X,y=smote.fit_resample(final_df[["df1","df2"]],final_df["target"])

# %%
X
# Out:
#            df1       df2
# 0     1.073546 -1.101339
# 1     0.755945 -1.172352
# 2     1.354479 -0.948528
# 3     3.103090  0.233485
# 4     1.951888 -0.270157
# ...        ...       ...
# 1785  1.150369  1.167342
# 1786  1.835373  0.014478
# 1787 -0.154248  1.957099
# 1788  1.069097  1.059562
# 1789 -0.089819  1.952588
#
# [1790 rows x 2 columns]

# %%
X=pd.DataFrame(X,columns=["df1","df2"])
y=pd.DataFrame(y,columns=["target"])
final_df=pd.concat([X,y],axis=1)
final_df
# Out:
#            df1       df2  target
# 0     1.073546 -1.101339       0
# 1     0.755945 -1.172352       0
# 2     1.354479 -0.948528       0
# 3     3.103090  0.233485       0
# 4     1.951888 -0.270157       0
# ...        ...       ...     ...
# 1785  1.150369  1.167342       1
# 1786  1.835373  0.014478       1
# 1787 -0.154248  1.957099       1
# 1788  1.069097  1.059562       1
# 1789 -0.089819  1.952588       1
#
# [1790 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
plt.scatter(final_df["df1"],final_df["df2"],c=final_df["target"])

# %%
lst_marks=[45,32,56,75,89,54,32,89,90,87,67,54,45,98,99,67,74]
import numpy as np

# %%
min,Q1,med,Q3,max=np.quantile(lst_marks,[0,0.25,0.5,0.75,1])

# %%
min,Q1,med,Q3,max
# Out:
# (32.0, 54.0, 67.0, 89.0, 99.0)

# %%
IQR=Q3-Q1
IQR
# Out:
# 35.0

# %%
lower_fence=Q1-1.5*(IQR)
higher_fence=Q3+1.5*(IQR)

# %%
lower_fence
# Out:
# 1.5

# %%
higher_fence
# Out:
# 141.5

# %%
import seaborn as sns
lst_marks=[45,32,56,75,89,54,32,89,90,87,67,54,45,98,99,67,74]

# %%
sns.boxplot(lst_marks)
